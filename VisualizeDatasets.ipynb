# %% [markdown]
# <a href="https://colab.research.google.com/github/zenitsu0705/DM/blob/main/VisualizeDatasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.array([0,6])
y = np.array([0,250])
plt.plot(x,y)
plt.show()

# %%
x = np.array([1,8])
y = np.array([3,10])
plt.plot(x,y,"*")
plt.show()

# %%
x = np.array([1,2,4,6,8])
y = np.array([3,8,1,10,250])
plt.plot(x,y)
plt.show()

# %%
y = np.array([3,8,1,10])
plt.plot(y,linestyle="dotted")
plt.show()

# %%
y = np.array([3,8,1,10])
plt.plot(y,linewidth="20")
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.title("sports watch data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
# Histrogram

# %%
x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
data = pd.read_csv('/content/diabetes.csv')

# %%
plt.figure(figsize=(10,7))
x = data["Glucose"]
plt.hist(x,bins=10,color="yellow")
plt.title("Glucose level in mm")
plt.xlabel("Glucose_Level_Mm")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(10,7))
x = data["Insulin"]
plt.hist(x,bins=10,color="pink")
plt.title("Insulin Level")
plt.xlabel("Insulin_Level")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Box Plot

# %%
np.random.seed(10)
data=np.random.normal(100,20,200)
fig=plt.figure(figsize=(10,7))
plt.boxplot(data)
plt.show()

# %%
np.random.seed(10)
data_1=np.random.normal(100,10,200)
data_2=np.random.normal(90,20,200)
data_3=np.random.normal(80,30,200)
data_4=np.random.normal(70,40,200)
data=[data_1,data_2,data_3,data_4]
fig=plt.figure(figsize=(10,7))
ax=fig.add_axes([0,0,1,1])
bp=ax.boxplot(data)
plt.show()

# %%
# Bar Chart

# %%
fig = plt.figure(figsize=(10,7))
x = fig.add_axes([0,0,1,1])
languages = ["c","c++","java","python"]
students = [15,25,30,47]
x.bar(languages,students)
plt.show()

# %%
# Pie Chart

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([25,35,16,50])
mylabels = ["c++","Java","C","Python"]
plt.pie(x,labels=mylabels)
plt.show()
